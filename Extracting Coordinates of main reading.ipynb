# %% [markdown]
# # Main Work Start

# %%
f = open("result.txt","r")
text = f.read()
f.close()

# %%
# for i,j  in enumerate(text.split("\n")):
#     print(i,j)

# %%
lis = text.split("\n")

# %%
lis

# %%
temp = []
for i in lis:
    if len(i)>0:
        if i[0]=="d":
            temp.append(i)

# %%
temp_1 = []
for i in temp:
    temp_1.append(i.split(":")[0][5:])

# %%
temp_1[55]
# Out:
# 'obj/Main_Folder16091210002020-05.jpg'

# %%
start = text.split("\n")[14:]

# %%
reading = []
i = 0
while i<len(start):
    if start[i][0]=="r" and start[i][0]=="r":
        reading.append(start[i])
        i+=2
        continue
    elif start[i][0]=="r":
        reading.append(start[i])
    i+=1

# %%
len(reading)
# Out:
# 1020

# %%
reading

# %%
coordinates = []
for i in reading:
    coordinates.append(i.split("\t")[1])

# %%
value = coordinates[0].split(" ")

# %%
temp_1[606]
# Out:
# 'obj/Main_Folder16691210002020-05.jpg'

# %%
coordinates[605]
# Out:
# '(left_x:  385   top_y:  374   width:   44   height:  197)'

# %%
import re

# %%
image = cv2.imread(temp_1[605])
plt.imshow(image)
plt.show()
crop = image[374:374+197,385:385+44]
plt.imshow(crop)
plt.show()

# %%
"obj/{}".format(images[0])
# Out:
# 'obj/Main_Folder00081210002020-05.jpg'

# %%
left_x = value[2]
top_y = value[7]
width = value[12]
height = value[-1][:-1]

# %%
left_x
# Out:
# '236'

# %%
int(top_y)
# Out:
# 333

# %%
plt.imshow(image)
plt.show()

# %%
cropped = image[int(top_y)-10:int(top_y)+int(height)+10,int(left_x):int(left_x)+int(width)+10]

# %%
plt.imshow(cropped)
plt.show()

# %%
len(coordinates)
# Out:
# 1020

# %%
len(temp_1)
# Out:
# 1020

# %% [markdown]
# # Saving the new image

# %%
for i,j in enumerate(temp_1):
    image = cv2.imread(j)
    value = [int(i) for i in coordinates[i].split(" ") if i.isdigit()]
#     print(value)
#     print(coordinates[i])
    left_x = value[0]
    top_y = value[1]
    width = value[2]
    height = coordinates[i].split(" ")[-1][0:-1]
    #print(i,left_x,top_y,width,height)
    try:
        cropped = image[int(top_y)-20:int(top_y)+int(height)+20,int(left_x)-20:int(left_x)+int(width)+20]
        #plt.imshow(cropped)
        #plt.show()
        cv2.imwrite("{}.jpg".format(i),cropped)
    except:
        print(i,temp_1[i])
# Out:
# 54 obj/Main_Folder02329952772020-05.jpg

# %%
temp_1[54]
# Out:
# 'obj/Main_Folder02329952772020-05.jpg'

# %%
temp_1[606]
# Out:
# 'obj/Main_Folder16691210002020-05.jpg'

# %%
[int(i) for i in coordinates[7].split(" ") if i.isdigit()]

# %%
coordinates[7].split(" ")
# Out:
# ['(left_x:',
#  '',
#  '286',
#  '',
#  '',
#  'top_y:',
#  '',
#  '232',
#  '',
#  '',
#  'width:',
#  '',
#  '',
#  '59',
#  '',
#  '',
#  'height:',
#  '',
#  '316)']

# %%
coordinates[0].split(" ")[-1][0:-1]
# Out:
# '97'

# %%
temp_1[54]
# Out:
# 'obj/Main_Folder02329952772020-05.jpg'

# %%
coordinates[54]
# Out:
# '(left_x:   71   top_y:    9   width:  386   height:  301)'

# %%
reading[54]
# Out:
# 'reading: 33%\t(left_x:   71   top_y:    9   width:  386   height:  301)'
